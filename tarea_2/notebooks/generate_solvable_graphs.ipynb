# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import networkx as nx
import matplotlib.pyplot as plt

from src.experiment.graph import CostReliabilityGraph  

# Draw the graph
plt.figure(figsize=(8, 6))
CostReliabilityGraph.generate_random_solvable_graph(4).draw()
plt.show()

# %%
# Out:
# [(0, {'reliability_sum': np.float64(2.385966259211388)}),
#  (1, {'reliability_sum': np.float64(2.053632858395596)}),
#  (2, {'reliability_sum': np.float64(2.098027225198365)}),
#  (3, {'reliability_sum': np.float64(1.8)})]
